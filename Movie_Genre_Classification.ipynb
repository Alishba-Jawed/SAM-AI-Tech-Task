# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishba-Jawed/SAM-AI-Tech-Task/blob/main/Movie_Genre_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel("/content/movie genres.xlsx")

# %%
data
# Out:
#        genre                            title  \
# 0      Drama                     12 Angry Men
# 1      Drama  One Flew Over the Cuckoo's Nest
# 2      Drama                             Hope
# 3      Drama                          Radical
# 4      Drama               American History X
# ...      ...                              ...
# 1169  Horror          Texas Chainsaw Massacre
# 1170  Comedy           Hot Tub Time Machine 2
# 1171  Comedy                   Vive la France
# 1172   Drama                           Cuties
# 1173  Horror                            Ouija
#
#                                                    text
# 0     The defense and the prosecution have rested an...
# 1     A petty criminal fakes insanity to serve his s...
# 2     After 8-year-old So-won narrowly survives a br...
# 3     In a Mexican border town plagued by neglect, c...
# 4     Derek Vineyard is paroled after serving 3 year...
# ...                                                 ...
# ...

# %%
data.isnull().sum()
# Out:
# genre    0
# title    0
# text     0
# dtype: int64

# %%
data.dtypes
# Out:
# genre    object
# title    object
# text     object
# dtype: object

# %% [markdown]
# **GENDER COLUMN**

# %%
data["genre"].mode()
# Out:
# 0    Drama
# Name: genre, dtype: object

# %%
data["genre"] = data["genre"].fillna(data["genre"].mode()[0]) #Filling Null Value in genre column

# %% [markdown]
# **TEXT COLUMN**

# %%
data["text"].mode()
# Out:
# 0    "Loro", in two parts, is a period movie that c...
# Name: text, dtype: object

# %%
data["text"] = data["text"].fillna(data["text"].mode()[0]) #Filling Null Value in text column

# %% [markdown]
# **VERFY DATA IS CLEAN**

# %%
data.isnull().sum()
# Out:
# genre    0
# title    0
# text     0
# dtype: int64

# %%
data["genre"] = data["genre"].str.split(", ").str[0]
print(data["genre"].nunique())
# Out:
# 3

# %%
X = data["text"] #Features

# %%
y = data["genre"] #Target

# %%
X
# Out:
# 0       The defense and the prosecution have rested an...
# 1       A petty criminal fakes insanity to serve his s...
# 2       After 8-year-old So-won narrowly survives a br...
# 3       In a Mexican border town plagued by neglect, c...
# 4       Derek Vineyard is paroled after serving 3 year...
#                               ...
# 1169    After nearly 50 years of hiding, Leatherface r...
# 1170    After their first adventure with the Hot Tub T...
# 1171    Muzafar and Feruz are two easy going shepherds...
# 1172    Amy, an 11-year-old girl, joins a group of dan...
# 1173    A group of friends must confront their most te...
# Name: text, Length: 1174, dtype: object

# %%
y
# Out:
# 0        Drama
# 1        Drama
# 2        Drama
# 3        Drama
# 4        Drama
#          ...
# 1169    Horror
# 1170    Comedy
# 1171    Comedy
# 1172     Drama
# 1173    Horror
# Name: genre, Length: 1174, dtype: object

# %%
print(len(X))
# Out:
# 1174

# %%
print(len(y))
# Out:
# 1174

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove punctuation & numbers
    text = re.sub(r'\s+', ' ', text).strip() # Remove extra spaces
    return text

data['text'] = data['text'].apply(clean_text)

# %% [markdown]
# Encoding Target

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# Training

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.30, random_state=42
)

# %% [markdown]
# Categorical to Numerical by TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(
    stop_words='english',
    max_features=50000
)

# %%
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec =  vectorizer.transform(X_test)

# %% [markdown]
# **NAIVE BAYES**

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
X_train = X_train.squeeze()
X_test = X_test.squeeze()

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (821,)
# (353,)

# %%
print(X_train_vec.shape)
print(X_test_vec.shape)
# Out:
# (821, 7531)
# (353, 7531)

# %%
nb.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = nb.predict(X_test_vec)

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6543909348441926

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 94  61   0]
#  [ 22 137   0]
#  [ 14  25   0]]

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import LinearSVC

# %%
svm = LinearSVC()

# %%
svm.fit(X_train_vec, y_train)
# Out:
# LinearSVC()

# %%
y_pred = svm.predict(X_test_vec)

# %% [markdown]
# **Evaluation**

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6685552407932012

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[106  49   0]
#  [ 39 119   1]
#  [ 11  17  11]]
